# %%
## Import the necessary libraries.

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
### Read the datasets

client_data = pd.read_csv("client_data (1) (1).csv")

price_data = pd.read_csv("price_data (1).csv")

# %%
client_data.head(3)
# Out:
#                                  id                     channel_sales  \
# 0  24011ae4ebbe3035111d65fa7c15bc57  foosdfpfkusacimwkcsosbicdxkicaua
# 1  d29c2c54acc38ff3c0614d0a653813dd                           MISSING
# 2  764c75f661154dac3a6c254cd082ea7d  foosdfpfkusacimwkcsosbicdxkicaua
#
#    cons_12m  cons_gas_12m  cons_last_month  date_activ    date_end  \
# 0         0         54946                0  2013-06-15  2016-06-15
# 1      4660             0                0  2009-08-21  2016-08-30
# 2       544             0                0  2010-04-16  2016-04-16
#
#   date_modif_prod date_renewal  forecast_cons_12m  ...  has_gas  imp_cons  \
# 0      2015-11-01   2015-06-23               0.00  ...        t       0.0
# 1      2009-08-21   2015-08-31             189.95  ...        f       0.0
# 2      2010-04-16   2015-04-17              47.96  ...        f       0.0
#
#    margin_gross_pow_ele  margin_net_pow_ele  nb_prod_act  net_margin  \
# ...

# %%
### read the datasets
price_data.head(3)
# Out:
#                                  id  price_date  price_off_peak_var  \
# 0  038af19179925da21a25619c5a24b745  2015-01-01            0.151367
# 1  038af19179925da21a25619c5a24b745  2015-02-01            0.151367
# 2  038af19179925da21a25619c5a24b745  2015-03-01            0.151367
#
#    price_peak_var  price_mid_peak_var  price_off_peak_fix  price_peak_fix  \
# 0             0.0                 0.0           44.266931             0.0
# 1             0.0                 0.0           44.266931             0.0
# 2             0.0                 0.0           44.266931             0.0
#
#    price_mid_peak_fix
# 0                 0.0
# 1                 0.0
# 2                 0.0

# %%
### check the info of the datasets.

client_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14606 entries, 0 to 14605
# Data columns (total 26 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              14606 non-null  object
#  1   channel_sales                   14606 non-null  object
#  2   cons_12m                        14606 non-null  int64
#  3   cons_gas_12m                    14606 non-null  int64
#  4   cons_last_month                 14606 non-null  int64
#  5   date_activ                      14606 non-null  object
#  6   date_end                        14606 non-null  object
#  7   date_modif_prod                 14606 non-null  object
#  8   date_renewal                    14606 non-null  object
#  9   forecast_cons_12m               14606 non-null  float64
#  10  forecast_cons_year              14606 non-null  int64
#  11  forecast_discount_energy        14606 non-null  float64
# ...

# %%
### check the info of the datasets.

price_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193002 entries, 0 to 193001
# Data columns (total 8 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   id                  193002 non-null  object
#  1   price_date          193002 non-null  object
#  2   price_off_peak_var  193002 non-null  float64
#  3   price_peak_var      193002 non-null  float64
#  4   price_mid_peak_var  193002 non-null  float64
#  5   price_off_peak_fix  193002 non-null  float64
#  6   price_peak_fix      193002 non-null  float64
#  7   price_mid_peak_fix  193002 non-null  float64
# dtypes: float64(6), object(2)
# memory usage: 11.8+ MB

# %%
### Check for Null values if there is.

client_data.isnull().sum()
# Out:
# id                                0
# channel_sales                     0
# cons_12m                          0
# cons_gas_12m                      0
# cons_last_month                   0
# date_activ                        0
# date_end                          0
# date_modif_prod                   0
# date_renewal                      0
# forecast_cons_12m                 0
# forecast_cons_year                0
# forecast_discount_energy          0
# forecast_meter_rent_12m           0
# forecast_price_energy_off_peak    0
# forecast_price_energy_peak        0
# forecast_price_pow_off_peak       0
# has_gas                           0
# imp_cons                          0
# margin_gross_pow_ele              0
# margin_net_pow_ele                0
# nb_prod_act                       0
# net_margin                        0
# num_years_antig                   0
# origin_up                         0
# pow_max                           0
# churn                             0
# ...

# %%
price_data.isnull().sum()
# Out:
# id                    0
# price_date            0
# price_off_peak_var    0
# price_peak_var        0
# price_mid_peak_var    0
# price_off_peak_fix    0
# price_peak_fix        0
# price_mid_peak_fix    0
# dtype: int64

# %%
import missingno as msn
msn.bar(price_data, color = 'Teal')
# Out:
# <Axes: >

# %%
### visualize the null values 


sns.heatmap(price_data.isnull(), color = "Teal")
# Out:
# <Axes: >

# %%
### Null values for Client Datasets.

msn.bar(client_data, color='Teal')
# Out:
# <Axes: >

# %%
sns.heatmap(client_data.isna(), color='Teal')
# Out:
# <Axes: >

# %%
### Check for duplicates values

client_data.duplicated().sum()
# Out:
# 0

# %%
price_data.duplicated().sum()
# Out:
# 0

# %%
### Describe the data

client_data.describe()
# Out:
#            cons_12m  cons_gas_12m  cons_last_month  forecast_cons_12m  \
# count  1.460600e+04  1.460600e+04     14606.000000       14606.000000
# mean   1.592203e+05  2.809238e+04     16090.269752        1868.614880
# std    5.734653e+05  1.629731e+05     64364.196422        2387.571531
# min    0.000000e+00  0.000000e+00         0.000000           0.000000
# 25%    5.674750e+03  0.000000e+00         0.000000         494.995000
# 50%    1.411550e+04  0.000000e+00       792.500000        1112.875000
# 75%    4.076375e+04  0.000000e+00      3383.000000        2401.790000
# max    6.207104e+06  4.154590e+06    771203.000000       82902.830000
#
#        forecast_cons_year  forecast_discount_energy  forecast_meter_rent_12m  \
# count        14606.000000              14606.000000             14606.000000
# mean          1399.762906                  0.966726                63.086871
# std           3247.786255                  5.108289                66.165783
# ...

# %%
### Describe the data

price_data.describe()
# Out:
#        price_off_peak_var  price_peak_var  price_mid_peak_var  \
# count       193002.000000   193002.000000       193002.000000
# mean             0.141027        0.054630            0.030496
# std              0.025032        0.049924            0.036298
# min              0.000000        0.000000            0.000000
# 25%              0.125976        0.000000            0.000000
# 50%              0.146033        0.085483            0.000000
# 75%              0.151635        0.101673            0.072558
# max              0.280700        0.229788            0.114102
#
#        price_off_peak_fix  price_peak_fix  price_mid_peak_fix
# count       193002.000000   193002.000000       193002.000000
# mean            43.334477       10.622875            6.409984
# std              5.410297       12.841895            7.773592
# min              0.000000        0.000000            0.000000
# 25%             40.728885        0.000000            0.000000
# ...

# %%
numerical_columns_client = client_data.select_dtypes(include = 'number')

# %%
list(numerical_columns_client.columns)
# Out:
# ['cons_12m',
#  'cons_gas_12m',
#  'cons_last_month',
#  'forecast_cons_12m',
#  'forecast_cons_year',
#  'forecast_discount_energy',
#  'forecast_meter_rent_12m',
#  'forecast_price_energy_off_peak',
#  'forecast_price_energy_peak',
#  'forecast_price_pow_off_peak',
#  'imp_cons',
#  'margin_gross_pow_ele',
#  'margin_net_pow_ele',
#  'nb_prod_act',
#  'net_margin',
#  'num_years_antig',
#  'pow_max',
#  'churn']

# %%
### Do a Visualization of some features of the Dataset.


sns.histplot(client_data['cons_12m'], kde = 'True', color = 'Blue')
# Out:
# <Axes: xlabel='cons_12m', ylabel='Count'>

# %%
sns.histplot(client_data['forecast_cons_12m'], kde = 'True', color = 'Blue')
# Out:
# <Axes: xlabel='forecast_cons_12m', ylabel='Count'>

# %%
### Concatenate the two datasets to give you one dataset.


new_data = pd.concat([client_data,price_data])
list(new_data.columns)
# Out:
# ['id',
#  'channel_sales',
#  'cons_12m',
#  'cons_gas_12m',
#  'cons_last_month',
#  'date_activ',
#  'date_end',
#  'date_modif_prod',
#  'date_renewal',
#  'forecast_cons_12m',
#  'forecast_cons_year',
#  'forecast_discount_energy',
#  'forecast_meter_rent_12m',
#  'forecast_price_energy_off_peak',
#  'forecast_price_energy_peak',
#  'forecast_price_pow_off_peak',
#  'has_gas',
#  'imp_cons',
#  'margin_gross_pow_ele',
#  'margin_net_pow_ele',
#  'nb_prod_act',
#  'net_margin',
#  'num_years_antig',
#  'origin_up',
#  'pow_max',
#  'churn',
#  'price_date',
#  'price_off_peak_var',
#  'price_peak_var',
#  'price_mid_peak_var',
#  'price_off_peak_fix',
#  'price_peak_fix',
#  'price_mid_peak_fix']

# %%
numerical= new_data.select_dtypes(include = "number")

(numerical.columns)
# Out:
# Index(['cons_12m', 'cons_gas_12m', 'cons_last_month', 'forecast_cons_12m',
#        'forecast_cons_year', 'forecast_discount_energy',
#        'forecast_meter_rent_12m', 'forecast_price_energy_off_peak',
#        'forecast_price_energy_peak', 'forecast_price_pow_off_peak', 'imp_cons',
#        'margin_gross_pow_ele', 'margin_net_pow_ele', 'nb_prod_act',
#        'net_margin', 'num_years_antig', 'pow_max', 'churn',
#        'price_off_peak_var', 'price_peak_var', 'price_mid_peak_var',
#        'price_off_peak_fix', 'price_peak_fix', 'price_mid_peak_fix'],
#       dtype='object')

# %%
numerical_client= client_data.select_dtypes(include = "number")
len(numerical_client.columns)
# Out:
# 18

# %%
num=(numerical_client).describe()
num
# Out:
#            cons_12m  cons_gas_12m  cons_last_month  forecast_cons_12m  \
# count  1.460600e+04  1.460600e+04     14606.000000       14606.000000
# mean   1.592203e+05  2.809238e+04     16090.269752        1868.614880
# std    5.734653e+05  1.629731e+05     64364.196422        2387.571531
# min    0.000000e+00  0.000000e+00         0.000000           0.000000
# 25%    5.674750e+03  0.000000e+00         0.000000         494.995000
# 50%    1.411550e+04  0.000000e+00       792.500000        1112.875000
# 75%    4.076375e+04  0.000000e+00      3383.000000        2401.790000
# max    6.207104e+06  4.154590e+06    771203.000000       82902.830000
#
#        forecast_cons_year  forecast_discount_energy  forecast_meter_rent_12m  \
# count        14606.000000              14606.000000             14606.000000
# mean          1399.762906                  0.966726                63.086871
# std           3247.786255                  5.108289                66.165783
# ...

# %%
### Do a Subplots to check the distribution of all numerical columns in both datasets.

fig,axes = plt.subplots(nrows=6, ncols=4, figsize=(20,20))
position = axes.flatten()
for idx,column_name in enumerate(numerical):
    sns.histplot(new_data[column_name], kde = True, color= 'Teal', ax = position[idx])
    plt.tight_layout()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_22340\570580116.py:7: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# C:\Users\hp\AppData\Local\Temp\ipykernel_22340\570580116.py:7: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# C:\Users\hp\AppData\Local\Temp\ipykernel_22340\570580116.py:7: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# C:\Users\hp\AppData\Local\Temp\ipykernel_22340\570580116.py:7: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# C:\Users\hp\AppData\Local\Temp\ipykernel_22340\570580116.py:7: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# C:\Users\hp\AppData\Local\Temp\ipykernel_22340\570580116.py:7: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# C:\Users\hp\AppData\Local\Temp\ipykernel_22340\570580116.py:7: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# ...

# %%
categorical_data = new_data.select_dtypes(include='object')
list(categorical_data.columns)
len((categorical_data.columns))
# Out:
# 9

# %%
#fig,axes = plt.subplots(nrows=3, ncols=3, figsize=(20,20))
#position = axes.flatten()
#for idx, column_name in enumerate(categorical_data):
    #sns.countplot(x=new_data[column_name], color ='Teal', ax = position[idx])
    #plt.tight_layout()

# %%
## Subplots to check for outliers.

#fig,axes = plt.subplots(nrows=6, ncols=4, figsize=(20,20))
#position = axes.flatten()
#for idx, column_name in enumerate(numerical):
    #sns.boxplot(new_data[column_name], color ='Teal', ax = position[idx])
    #plt.tight_layout()

# %%
### Doing Bivaraiate Analysis. 

## Numerical vs Categorical

sns.barplot(data=new_data, x='churn', y='cons_12m', errorbar=None, color = 'Green')
# Out:
# <Axes: xlabel='churn', ylabel='cons_12m'>

# %%
sns.barplot(data=new_data, x='churn', y='cons_gas_12m', color='Green', errorbar=None)
# Out:
# <Axes: xlabel='churn', ylabel='cons_gas_12m'>

# %%
sns.barplot(data=new_data, x='churn', y='nb_prod_act',errorbar=None, color= 'Teal')
# Out:
# <Axes: xlabel='churn', ylabel='nb_prod_act'>

# %%
### Multivaraiate Analysis.



sns.barplot(data= new_data, x='churn', y='imp_cons', hue='has_gas', palette= 'Set3', errorbar=None)


# Considered 3 features together, namely
# x = churn
# y = imp_cons
# hue = has_gas
# Out:
# <Axes: xlabel='churn', ylabel='imp_cons'>

# %%
sns.barplot(data=new_data, x='churn',y='num_years_antig', hue='has_gas', palette='Set3', errorbar=None)
# Out:
# <Axes: xlabel='churn', ylabel='num_years_antig'>

# %%
sns.barplot(data=new_data, x='churn', y='forecast_cons_12m', hue='has_gas', palette='Set3', errorbar=None)
# Out:
# <Axes: xlabel='churn', ylabel='forecast_cons_12m'>
